# %% [markdown]
# <a href="https://colab.research.google.com/github/vidushi1920/Customer-Personality-Analysis/blob/main/Data_Analysis_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/Book1.csv')
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#      ID  Year_Birth   Education  ... Z_CostContact  Z_Revenue  Response
# 0  5524        1957  Graduation  ...             3         11         1
# 1  2174        1954  Graduation  ...             3         11         0
# 2  4141        1965  Graduation  ...             3         11         0
# 3  6182        1984  Graduation  ...             3         11         0
# 4  5324        1981         PhD  ...             3         11         0
#
# [5 rows x 29 columns]

# %%
#checking for null values
df.info()
#no null values in the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['Present Age'] = 2000 - df['Year_Birth'] + 21

# %%
avg_age = sum(list(df['Present Age']))/len(df['Present Age'])
avg_age
# Out:
# 52.19419642857143

# %%
df['Present Age'].head()
# Out:
# 0    64
# 1    67
# 2    56
# 3    37
# 4    40
# Name: Present Age, dtype: int64

# %%
df['TotalPurchaseThroughCampaign'] = df['AcceptedCmp2'] + df['AcceptedCmp3'] + df['AcceptedCmp4'] + df['AcceptedCmp5']  + df['AcceptedCmp1'] + df['Response']

# %%
sns.heatmap(data = df[['AcceptedCmp2','AcceptedCmp3','AcceptedCmp4','AcceptedCmp5','AcceptedCmp1','Response','TotalPurchaseThroughCampaign']].corr(),annot = True)

# %%
df['TotalPurchaseThroughCampaign'].head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: TotalPurchaseThroughCampaign, dtype: int64

# %%
sns.set(rc={'figure.figsize':(25,20)})
hm = sns.heatmap(data = df.corr(),annot=True)

# %%
df.corr()
# Out:
#                                     ID  ...  TotalPurchaseThroughCampaign
# ID                            1.000000  ...                     -0.036884
# Year_Birth                    0.000028  ...                      0.008302
# Income                        0.013095  ...                      0.287984
# Kidhome                       0.002406  ...                     -0.193419
# Teenhome                     -0.002580  ...                     -0.159110
# Recency                      -0.046524  ...                     -0.088962
# MntWines                     -0.022878  ...                      0.489211
# MntFruits                     0.004600  ...                      0.172769
# MntMeatProducts              -0.004437  ...                      0.330172
# MntFishProducts              -0.024475  ...                      0.180003
# MntSweetProducts             -0.007642  ...                      0.199489
# MntGoldProds                 -0.013438  ...                      0.203533
# ...

# %%
count = 0
for i in df['AcceptedCmp3']:
  if i == 1:
    count = count+1
print((count/2240)*100)
# Out:
# 7.276785714285714

# %%
count = 0
for i in df['AcceptedCmp1']:
  if i == 1:
    count = count+1
print((count/2240)*100)
# Out:
# 6.428571428571428

# %%
count = 0
for i in df['AcceptedCmp2']:
  if i == 1:
    count = count+1
print((count/2240)*100)
# Out:
# 1.3392857142857142

# %%
count = 0
for i in df['AcceptedCmp4']:
  if i == 1:
    count = count+1
print((count/2240)*100)
# Out:
# 7.455357142857142

# %%
count = 0
for i in df['AcceptedCmp5']:
  if i == 1:
    count = count+1
print((count/2240)*100)
# Out:
# 7.276785714285714

# %%
count = 0
for i in df['Response']:
  if i == 1:
    count = count+1
print((count/2240)*100)
# Out:
# 14.910714285714285

# %%
#point 1
#as seen from the table above,with time number of purchases through campaign have increased significantly ,almost doubled from the first one

# %%
df[['Present Age','Response']].corr()
# Out:
#              Present Age  Response
# Present Age     1.000000 -0.021325
# Response       -0.021325  1.000000

# %%
#point 2
#Older audience are expected to respond less to the campaigns

# %%
plt.figure(figsize=(10,7))
l,a = list(set(data["Education"])),[]
for i in range(len(l)):
    a.append(data["Education"].to_list().count(l[i]))
    l[i] = l[i]+" ("+str(a[i]*100/len(data["Education"])) + " %)"
plt.pie(a,labels=l, radius=2)
plt.show()

# %%
np.unique(df['Education'])
# Out:
# array(['2n Cycle', 'Basic', 'Graduation', 'Master', 'PhD'], dtype=object)

# %%
sns.displot(x="Education",y="Kidhome",data=data)

# %%
sns.displot(x="Education",y="Response",data=data)

# %%
#Educated customers seem to respond to campaigns more.

# %%
#from the correlation matrix,it becomes clear that grocery items such as fruits,meat,fish and sweet products are always brought together.
#there is a strong correlation between catalog purchases and wine,meat purchases indicating people responding to aesthetic gourmet marketing through catalog.

# %%
#People with higher income tend to make a purchase directly through store
#And with higher income,they also tend to buy expensive items such as meat,wine

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.heatmap(df[['Income','NumStorePurchases']].corr(),annot=True)

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.countplot(x='Marital_Status',data=df)

# %%
df['Present Age'].head()
# Out:
# 0    64
# 1    67
# 2    56
# 3    37
# 4    40
# Name: Present Age, dtype: int64

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.countplot(x = df['Present Age'],data=df)

# %%
#we mostly cater to middle aged and old aged audience 
#customers with kids at home prefer to buy through website because it is more convenient for the young parents/new parents

# %%
#wines are also purchased along with other general grocery items indicating the purchase of a full course meal along with the wine.
#Wine buyer prefer to buy their bottles of prefernce directly from the store

# %%
#perisable grocery items such as fruits,meat are preffered to buy from the store

# %%
#People with higher income have the privelege of purchasing through catalog
